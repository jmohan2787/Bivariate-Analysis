# %% [markdown]
# <a href="https://colab.research.google.com/github/jmohan2787/Bivariate-Analysis/blob/main/Infrenential_analysis_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path='/content/drive/MyDrive/Dataset/Placement.csv'
data=pd.read_csv(path)

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# 1)Replace the NaN values with correct value. And justify why you have
# chosen the same. **bold text**

# %%
data['salary'].fillna(0,inplace=True)
# Out:
# <ipython-input-5-b0b420d1f09e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['salary'].fillna(0,inplace=True)

# %%
data['salary'].fillna(data['salary'].median(),inplace=True)
# Out:
# <ipython-input-6-02bfc1298fd2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['salary'].fillna(data['salary'].median(),inplace=True)

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# *** 2)How many of them are not placed?***

# %%
Not_placed_data=data[data['status']=='Not Placed']

# %%
Not_placed_data.describe()
# Out:
#             sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# count   67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   110.477612  57.544030  58.395522  61.134179  69.587910  61.612836
# std     65.859667   8.394246   9.914090   6.365825  11.930687   5.705689
# min      4.000000  40.890000  37.000000  50.000000  50.000000  51.210000
# 25%     48.500000  52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    107.000000  56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    170.500000  63.000000  64.000000  65.000000  76.500000  65.405000
# max    215.000000  77.800000  82.000000  79.000000  97.000000  75.710000
#
#        salary
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %% [markdown]
# Conclusion: 67 student are not placed

# %%
Quan_Not_placed=[i for i in Not_placed_data.columns if Not_placed_data[i].dtypes!='O']

# %%
Quan_Not_placed
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
data_Not_placed=pd.DataFrame(index=['Mean','Median','Mode','Q1:25%','Q2:50%','Q3:75%','80%','85%','90%','95%','99%','Q4:100%','IQR','1.5IQR','LesserIQR','GreaterIQR','Min','Max'],columns=Quan_Not_placed)

# %%
import numpy as np

# %%
for i in Quan_Not_placed  :
  data_Not_placed.loc['Mean',i]=Not_placed_data[i].mean()
  data_Not_placed.loc['Median',i]=Not_placed_data[i].median()
  data_Not_placed.loc['Mode',i]=Not_placed_data[i].mode()[0]
  data_Not_placed.loc['Q1:25%',i]=Not_placed_data.describe()[i]['25%']
  data_Not_placed.loc['Q2:50%',i]=Not_placed_data.describe()[i]['50%']
  data_Not_placed.loc['Q3:75%',i]=Not_placed_data.describe()[i]['75%']
  data_Not_placed.loc['80%',i]=np.percentile(Not_placed_data[i],80)
  data_Not_placed.loc['85%',i]=np.percentile(Not_placed_data[i],85)
  data_Not_placed.loc['90%',i]=np.percentile(Not_placed_data[i],90)
  data_Not_placed.loc['95%',i]=np.percentile(Not_placed_data[i],95)
  data_Not_placed.loc['99%',i]=np.percentile(Not_placed_data[i],99)
  data_Not_placed.loc['Q4:100%',i]=Not_placed_data.describe()[i]['max']
  data_Not_placed.loc['IQR',i]=data_Not_placed.loc['Q3:75%',i]-data_Not_placed.loc['Q1:25%',i]
  data_Not_placed.loc['1.5IQR',i]=1.5*data_Not_placed.loc['IQR',i]
  data_Not_placed.loc['LesserIQR',i]=data_Not_placed.loc['Q1:25%',i]-data_Not_placed.loc['1.5IQR',i]
  data_Not_placed.loc['GreaterIQR',i]=data_Not_placed.loc['Q3:75%',i]+data_Not_placed.loc['1.5IQR',i]
  data_Not_placed.loc['Min',i]=Not_placed_data[i].min()
  data_Not_placed.loc['Max',i]=Not_placed_data[i].max()

# %%
data_Not_placed
# Out:
#                  sl_no     ssc_p      hsc_p   degree_p   etest_p      mba_p  \
# Mean        110.477612  57.54403  58.395522  61.134179  69.58791  61.612836
# Median           107.0     56.28      60.33       61.0      67.0      60.69
# Mode                 4      52.0       62.0       65.0      60.0      51.21
# Q1:25%            48.5      52.0       51.0       57.0      60.0      58.48
# Q2:50%           107.0     56.28      60.33       61.0      67.0      60.69
# Q3:75%           170.5      63.0       64.0       65.0      76.5     65.405
# 80%              179.2     63.38       65.8       65.0      79.0      65.93
# 85%              185.2      67.0      67.02      65.64      84.1     67.028
# 90%              190.4     68.34       70.0      68.03      87.7      69.13
# 95%              201.1    70.773     73.856      73.61    91.769     71.861
# 99%             211.04    76.612    79.5778      78.01    96.109     74.951
# ...

# %%
Quan_placed=[i for i in Not_placed_data.columns if Not_placed_data[i].dtypes!='O']

# %%
Quan_placed
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
placed_data=data[data['status']=='Placed']

# %%
placed_data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
# **4)What kind of relation between salary and mba_p**

# %%
data_placed=pd.DataFrame(index=['Mean','Median','Mode','Q1:25%','Q2:50%','Q3:75%','80%','85%','90%','95%','99%','Q4:100%','IQR','1.5IQR','LesserIQR','GreaterIQR','Min','Max'],columns=Quan_placed)

# %%
for i in Quan_placed  :
  data_placed.loc['Mean',i]=placed_data[i].mean()
  data_placed.loc['Median',i]=placed_data[i].median()
  data_placed.loc['Mode',i]=placed_data.describe()[i].mode()[0]
  data_placed.loc['Q1:25%',i]=placed_data.describe()[i]['25%']
  data_placed.loc['Q2:50%',i]=placed_data.describe()[i]['50%']
  data_placed.loc['Q3:75%',i]=placed_data.describe()[i]['75%']
  data_placed.loc['80%',i]=np.percentile(placed_data[i],80)
  data_placed.loc['85%',i]=np.percentile(placed_data[i],85)
  data_placed.loc['90%',i]=np.percentile(placed_data[i],90)
  data_placed.loc['95%',i]=np.percentile(placed_data[i],95)
  data_placed.loc['99%',i]=np.percentile(placed_data[i],99)
  data_placed.loc['Q4:100%',i]=placed_data.describe()[i]['max']
  data_placed.loc['IQR',i]=data_placed.loc['Q3:75%',i]-data_placed.loc['Q1:25%',i]
  data_placed.loc['1.5IQR',i]=1.5*data_placed.loc['IQR',i]
  data_placed.loc['LesserIQR',i]=data_placed.loc['Q1:25%',i]-data_placed.loc['1.5IQR',i]
  data_placed.loc['GreaterIQR',i]= data_placed.loc['Q3:75%',i]+data_placed.loc['1.5IQR',i]
  data_placed.loc['Min',i]=placed_data.describe()[i]['min']
  data_placed.loc['Max',i]=placed_data.describe()[i]['max']

# %%
data_placed
# Out:
#                  sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean        106.878378  71.721486  69.926554  68.740541  73.238041  62.579392
# Median           108.5       72.5       68.0       68.0       72.0     62.245
# Mode               1.0   8.715445   9.329268   6.518087  13.729333   5.884583
# Q1:25%           57.75       65.0       63.0       65.0       60.0    57.7725
# Q2:50%           108.5       72.5       68.0       68.0       72.0     62.245
# Q3:75%          153.25     78.125      75.25    72.4225       85.0      66.76
# 80%              164.6       80.0       77.6       73.0      87.33     68.054
# 85%             178.95       82.0       79.0     75.475       89.0    69.0475
# 90%              194.6       84.0       82.0     77.636       93.4     70.895
# 95%             204.65       85.0    89.7845      79.65     95.299    72.6085
# 99%             212.53      87.53      94.65      84.53     97.212    76.2224
# ...

# %% [markdown]
# **Concultion: 95% student hey have scored 79 t0 85% in ssc_p,hsc_p,degree_p and  nearly 95% scored in entrance test  and they also scored 76% in mba. **

# %% [markdown]
# **4)What kind of relation between salary and mba_p**

# %%
data_placed[Quan_placed].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000  0.682106  0.689113  0.558094  0.867561  0.598922  0.627869
# ssc_p     0.682106  1.000000  0.989085  0.980192  0.948456  0.990720  0.723363
# hsc_p     0.689113  0.989085  1.000000  0.983717  0.941754  0.985466  0.805188
# degree_p  0.558094  0.980192  0.983717  1.000000  0.882293  0.994920  0.761180
# etest_p   0.867561  0.948456  0.941754  0.882293  1.000000  0.911646  0.720055
# mba_p     0.598922  0.990720  0.985466  0.994920  0.911646  1.000000  0.724827
# salary    0.627869  0.723363  0.805188  0.761180  0.720055  0.724827  1.000000

# %% [markdown]
# The relation between Salary and mba_p is that 72%, mean that 72% of student they have scored 72% and they got 72% in salary

# %% [markdown]
# *** 5)Which specialization is getting minimum salary?***

# %%
placed_data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
placed_data['salary'].min()
# Out:
# 200000.0

# %%
min_salary=placed_data[placed_data['salary']==placed_data['salary'].min()]

# %%
min_salary['specialisation'].unique()
# Out:
# array(['Mkt&Fin', 'Mkt&HR'], dtype=object)

# %% [markdown]
# \specialisation in 'Mkt&Fin', 'Mkt&HR' are getting minimum salary 2Lahks

# %% [markdown]
# *** 6)How many of them getting above 500000 salary?***

# %%
salary_greater_than_5L=placed_data[placed_data['salary'] > float(500000)]

# %%
salary_greater_than_5L
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
greaterSalary=salary_greater_than_5L.shape[0]

# %%
greaterSalary
# Out:
# 3

# %% [markdown]
# Total #3 student they are getting greater than 5Lahks in salary

# %% [markdown]
#  ***7)Test the Analysis of Variance between etest_p and mba_p at signifance
# level 5%.(Make decision using Hypothesis Testing)***

# %%
import scipy.stats as stats

# %%
stats.f_oneway(placed_data['etest_p'],placed_data['mba_p'])
# Out:
# F_onewayResult(statistic=np.float64(75.35669909200762), pvalue=np.float64(2.7511196898832345e-16))

# %% [markdown]
# Conclusion: Pvalue gives us 2.75*e-16, so which is less than 0.05% as per Hypothesis test we should considered the Alternate Hypothesis

# %% [markdown]
# **8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make
# decision using Hypothesis Testing)**

# %%
sim_degree_t_SciTech=placed_data[placed_data['degree_t']=='Sci&Tech']['salary']

# %%
sim_specialisation_Mkt_HR=placed_data[placed_data['specialisation']=='Mkt&HR']['salary']

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(sim_degree_t_SciTech,sim_specialisation_Mkt_HR)
# Out:
# TtestResult(statistic=np.float64(2.734391160944239), pvalue=np.float64(0.007496896218767113), df=np.float64(92.0))

# %% [markdown]
# **Conclusion: Pvalue 0.0074 is lessthan 0.05% Which measn condition is true so we need to considered Alternate Hypothesis**

# %% [markdown]
#  **9)Convert the normal distribution to standard normal distribution for
# salary**

# %%
def std_deviation(column_name):
  import seaborn as sns
  mean=column_name.mean()
  std=column_name.std()
  change_in_list=[i for i in column_name]
  z_score=[((j-mean)/std) for j in change_in_list]
  sns.distplot(z_score)
  return sum(z_score)/len(z_score)

# %%
std_deviation(placed_data['salary'])
# Out:
# <ipython-input-72-181b13cd092b>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score)
# np.float64(1.7478511130923073e-16)

# %% [markdown]
# **10)What is the probability Density Function of the salary range from
# 700000 to 900000?**

# %%
import seaborn as sns
from matplotlib import pyplot
from scipy.stats import norm

# %%
def get_pdf(dataset,startrange,endrange):
  ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
  pyplot.axvline(startrange,color='Red')
  pyplot.axvline(endrange,color='Red')
  sample=dataset
  sample_mean=sample.mean()
  sample_std=sample.std()
  dist=norm(sample_mean,sample_std)
  values=[i for i in range(startrange,endrange)]
  probality=[dist.pdf(value) for value in values]
  prob=sum(probality)
  print('xx',prob)
  return prob

# %%
get_pdf(placed_data['salary'],700000,900000)
# Out:
# <ipython-input-122-ed41405cfac2>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# xx 5.377578376230696e-06
# np.float64(5.377578376230696e-06)

# %% [markdown]
# Conclusion: very few people salary getting range between 7Lahks to 9 Lahks

# %% [markdown]
#  **11)Test the similarity between the degree_t(Sci&Tech)with respect to
# etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)**

# %%
from scipy.stats import ttest_ind

# %%
degree_t_Sci_Tech_etest_p=placed_data[placed_data['degree_t']=='Sci&Tech']['etest_p']

# %%
degree_t_Sci_Tech_mba_p=placed_data[placed_data['degree_t']=='Sci&Tech']['mba_p']

# %%
ttest_ind(degree_t_Sci_Tech_etest_p,degree_t_Sci_Tech_mba_p)
# Out:
# TtestResult(statistic=np.float64(4.286330847883898), pvalue=np.float64(5.027752902669624e-05), df=np.float64(80.0))

# %% [markdown]
# Conclusion: Pvalue is greater than 0.05% which means condition True so we need to considered Alternate hypothesis

# %% [markdown]
# **12)Which parameter is highly correlated with salary?**

# %%
Quan=[i for i in placed_data.columns if placed_data[i].dtype != 'O']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
placed_data[Quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# Conclusion: Based on above chart etest_p 17.83% corrlated with salary. and mba_p 17.5% is corrlated with salary

# %% [markdown]
# **13) plot any useful graph and explain it.** *italicized text*

# %%
from matplotlib import pyplot as plt
sns.barplot(data=placed_data, x='workex', y='salary')
plt.title('Average Salary by Work Experience')
plt.show()

# %% [markdown]
# Conclusion: Those are experiance people getting salary greater than 2.7Lahks

# %%
# specialisation
from matplotlib import pyplot as plt
sns.barplot(data=placed_data, x='specialisation', y='salary')
plt.title('Average Salary by specialisation')
plt.show()

# %% [markdown]
# Conclusion: Those are specialisation in Mkt&Fin people getting salary greater than 2.7Lahks

# %%
# specialisation
from matplotlib import pyplot as plt
sns.pairplot(data=placed_data)
plt.title('pairplot')
plt.show()
